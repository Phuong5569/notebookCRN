# %%
examples = [
  {"input": "sửa: So 3 Nguyen Ngoc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Wu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu, Ha Nol", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},

  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, Ha Nol", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},

  {"input": "sửa: 58 Thai Thinh, Dong Da, Ha Nol", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},

  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien Hoa, Dong Nal", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},

  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy, Ha Nol", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},

  {"input": "sửa: 40 Cat Linh, Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, Dong Da, Ha Nol", "target": "40 Cát Linh, Đống Đa, Hà Nội"},

  {"input": "sửa: phong 101, tang 1, lo 04-TT5B, khu do thi Tay Nam Linh Dam", "target": "phòng 101, tầng 1, lô 04-TT5B, khu đô thị Tây Nam Linh Đàm"},

  {"input": "sửa: Nha 87 ngo 416 De La Thanh", "target": "Nhà 87 ngõ 416 Đê La Thành"},

  {"input": "sửa: Up coworking Space, 89 Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 Lang Ha, Ha Nol", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: 192 Ngo Duc Ke, quan 1, Ho Chi Minh", "target": "192 Ngô Đức Kế, quận 1, Hồ Chí Minh"},

  {"input": "sửa: so 5 Cong Truong Me Linh, phuong Ben Nghe, quan 1", "target": "số 5 Công Trường Mê Linh, phường Bến Nghé, quận 1"},

  {"input": "sửa: 90A duong Mai Xuan Thuong, tinh Gia Lai", "target": "90A đường Mai Xuân Thưởng, tỉnh Gia Lai"},
  {"input": "sửa: 96/7/12B Pham Van Dong, thanh pho Pleiku", "target": "96/7/12B Phạm Văn Đồng, thành phố Pleiku"},

  {"input": "sửa: 168 Ngo Gia Tu, thanh pho Ha Tinh", "target": "168 Ngô Gia Tự, thành phố Hà Tĩnh"},

  {"input": "sửa: So 253 duong Tran Phu", "target": "Số 253 đường Trần Phú"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach, Huyen Nam Sach", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách, Huyện Nam Sách"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach, Huyen Nam Sach, Hai Duong", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách, Huyện Nam Sách, Hải Dương"},

  {"input": "sửa: So 3 Nguyen Ngoc u, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen goc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu  Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu,Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen gNoc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngco Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc uV, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So  Nguyen Ngoc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So3 Nguyen Ngoc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},

  {"input": "sửa: So 30 Nguyen ong, Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, ang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, ong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, a Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, Ha oi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen oHng, Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},
  {"input": "sửa: So 30 Nguyen Hnog, Lang Ha, Dong Da, Ha Noi", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},

  {"input": "sửa: 58 hai Thinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai hinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, ong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, Dong a, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, Dong Da Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, Dong Da, a Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58 Thai Thinh, Dong Da, Ha oi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa:  Thai Thinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 5 Thai Thinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},
  {"input": "sửa: 58Thai Thinh, Dong Da, Ha Noi", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},

  {"input": "sửa: So 70/8 khu pho 5B, phuong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/ khu pho 5B, phuong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu ho 5B, phuong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho B, phuong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B phuong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, huong Tan Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong an Bien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan ien, Bien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien ien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, ien Hoa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien oa, Dong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien Hoa ong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien Hoa, ong Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien Hoa, Dong ai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},

  {"input": "sửa: inh Trung Plaza, B, 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh rung Plaza, B, 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung laza, B, 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza , 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B 255-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 55-257 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-57 duong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 uong Hung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong ung Vuong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung uong, phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vuong phuong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vuong, huong Vinh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vuong, phuong inh Trung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vuong, phuong Vinh rung", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương, phường Vĩnh Trung"},

  {"input": "sửa: oa nha 34T, Hoang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa ha 34T, Hoang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 4T, Hoang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T Hoang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, oang Dao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang ao Thuy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang Dao huy, Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy Ha Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy, a Noi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy, Ha oi", "target": "Tòa nhà 34T, Hoàng Đạo Thúy, Hà Nội"},

  {"input": "sửa: 0 Cat Linh, Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 4 Cat Linh, Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 at Linh, Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat inh, Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh Dong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, ong Da, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, Dong a, Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, Dong Da Ha Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, Dong Da, a Noi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},
  {"input": "sửa: 40 Cat Linh, Dong Da, Ha oi", "target": "40 Cát Linh, Đống Đa, Hà Nội"},

  {"input": "sửa: Up cowrking Space, 89 Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking pace, 89 Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space 89 Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space,  Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 8 Lang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 ang Ha, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 Lang a, Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 Lang Ha Ha Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 Lang Ha, a Noi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: Up coworking Space, 89 Lang Ha, Ha oi", "target": "Up coworking Space, 89 Láng Hạ, Hà Nội"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach, Huyen Nam Sach, Hai Duong", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách, Huyện Nam Sách, Hải Dương"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach, Huyen Nam Sach, Hai Duong", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách, Huyện Nam Sách, Hải Dương"},
  {"input": "sửa: So 253 duong Tran Phu, Thi tran Nam Sach, Huyen Nam Sach, Hai Duong", "target": "Số 253 đường Trần Phú, Thị trấn Nam Sách, Huyện Nam Sách, Hải Dương"},

  {"input": "sửa: So 3 Nguyen Ngoc Vu", "target": "Số 3 Nguyễn Ngọc Vũ"},
  {"input": "sửa: Dong Da, Ha Noi", "target": "Đống Đa, Hà Nội"},
  {"input": "sửa: phuong Ben Nghe", "target": "phường Bến Nghé"},
  {"input": "sửa: thanh pho Ho Chi Minh", "target": "thành phố Hồ Chí Minh"},
  {"input": "sửa: Toa nha 34T", "target": "Tòa nhà 34T"},
  {"input": "sửa: khu do thi", "target": "khu đô thị"},
  {"input": "sửa: Lang Ha", "target": "Láng Hạ"},
  {"input": "sửa: Nha 87 ngo 416", "target": "Nhà 87 ngõ 416"},
  {"input": "sửa: phong 101, tang 1", "target": "phòng 101, tầng 1"},
  {"input": "sửa: Cong Truong Me Linh", "target": "Công Trường Mê Linh"},
  {"input": "sửa: duong Mai Xuan Thuong", "target": "đường Mai Xuân Thưởng"},
  {"input": "sửa: Pham Van Dong", "target": "Phạm Văn Đồng"},
  {"input": "sửa: Ngo Gia Tu", "target": "Ngô Gia Tự"},
  {"input": "sửa: duong Tran Phu", "target": "đường Trần Phú"},
  {"input": "sửa: Thi tran Nam Sach", "target": "Thị trấn Nam Sách"},
  {"input": "sửa: Huyen Nam Sach", "target": "Huyện Nam Sách"},
  {"input": "sửa: Hai Duong", "target": "Hải Dương"},
  {"input": "sửa: tinh Gia Lai", "target": "tỉnh Gia Lai"},
  {"input": "sửa: quan 1", "target": "quận 1"},
  {"input": "sửa: so 5", "target": "số 5"},
  {"input": "sửa: Thai Thinh", "target": "Thái Thịnh"},
  {"input": "sửa: Cat Linh", "target": "Cát Linh"},
  {"input": "sửa: De La Thanh", "target": "Đê La Thành"},
  {"input": "sửa: Bien Hoa", "target": "Biên Hòa"},
  {"input": "sửa: Tan Bien", "target": "Tân Biên"},
  {"input": "sửa: Hung Vuong", "target": "Hùng Vương"},
  {"input": "sửa: Vinh Trung", "target": "Vĩnh Trung"},
  {"input": "sửa: Hoang Dao Thuy", "target": "Hoàng Đạo Thúy"},
  {"input": "sửa: Tay Nam Linh Dam", "target": "Tây Nam Linh Đàm"},
  {"input": "sửa: Ngo Duc Ke", "target": "Ngô Đức Kế"},
  {"input": "sửa: Ho Chi Minh", "target": "Hồ Chí Minh"},
  {"input": "sửa: Ben Nghe", "target": "Bến Nghé"},
  {"input": "sửa: thanh pho Ha Tinh", "target": "thành phố Hà Tĩnh"},
  {"input": "sửa: thanh pho Pleiku", "target": "thành phố Pleiku"},
  {"input": "sửa: Dong Nai", "target": "Đồng Nai"},
  {"input": "sửa: khu pho 5B", "target": "khu phố 5B"},
  {"input": "sửa: phuong Tan Bien", "target": "phường Tân Biên"},
  {"input": "sửa: phuong Vinh Trung", "target": "phường Vĩnh Trung"},

  {"input": "sửa: So 3 Nguyen Ngoc Wu", "target": "Số 3 Nguyễn Ngọc Vũ"},
  {"input": "sửa: S0 3 Nguyen Ngoc Vu", "target": "Số 3 Nguyễn Ngọc Vũ"},
  {"input": "sửa: So 3 Nguyen Ng0c Vu", "target": "Số 3 Nguyễn Ngọc Vũ"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu, Ha N0i", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: So 3 Nguyen Ngoc Vu, Ha Nol", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},
  {"input": "sửa: S0 3 Nguyen Ngoc Vu, Ha Noi", "target": "Số 3 Nguyễn Ngọc Vũ, Hà Nội"},

  {"input": "sửa: So 30 Nguyen H0ng", "target": "Số 30 Nguyên Hồng"},
  {"input": "sửa: So 3O Nguyen Hong", "target": "Số 30 Nguyên Hồng"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha", "target": "Số 30 Nguyên Hồng, Láng Hạ"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, D0ng Da", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa"},
  {"input": "sửa: So 30 Nguyen Hong, Lang Ha, Dong Da, Ha N0i", "target": "Số 30 Nguyên Hồng, Láng Hạ, Đống Đa, Hà Nội"},

  {"input": "sửa: 58 Thai Thinh", "target": "58 Thái Thịnh"},
  {"input": "sửa: 5B Thai Thinh", "target": "58 Thái Thịnh"},
  {"input": "sửa: 58 Thai ThInh", "target": "58 Thái Thịnh"},
  {"input": "sửa: 58 Thai Thinh, D0ng Da", "target": "58 Thái Thịnh, Đống Đa"},
  {"input": "sửa: 58 Thai Thinh, Dong Da", "target": "58 Thái Thịnh, Đống Đa"},
  {"input": "sửa: 58 Thai Thinh, Dong Da, Ha N0i", "target": "58 Thái Thịnh, Đống Đa, Hà Nội"},

  {"input": "sửa: So 37O/8 khu pho 5B", "target": "Số 370/8 khu phố 5B"},
  {"input": "sửa: So 370/B khu pho 5B", "target": "Số 370/8 khu phố 5B"},
  {"input": "sửa: So 370/8 khu ph0 5B", "target": "Số 370/8 khu phố 5B"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien", "target": "Số 370/8 khu phố 5B, phường Tân Biên"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan BIen", "target": "Số 370/8 khu phố 5B, phường Tân Biên"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien H0a", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa"},
  {"input": "sửa: So 370/8 khu pho 5B, phuong Tan Bien, Bien Hoa, D0ng Nai", "target": "Số 370/8 khu phố 5B, phường Tân Biên, Biên Hòa, Đồng Nai"},

  {"input": "sửa: Vinh Trung PIaza", "target": "Vĩnh Trung Plaza"},
  {"input": "sửa: VInh Trung Plaza", "target": "Vĩnh Trung Plaza"},
  {"input": "sửa: Vinh Trung Plaza, B", "target": "Vĩnh Trung Plaza, B"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257", "target": "Vĩnh Trung Plaza, B, 255-257"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 du0ng", "target": "Vĩnh Trung Plaza, B, 255-257 đường"},
  {"input": "sửa: Vinh Trung Plaza, B, 255-257 duong Hung Vu0ng", "target": "Vĩnh Trung Plaza, B, 255-257 đường Hùng Vương"},

  {"input": "sửa: T0a nha 34T", "target": "Tòa nhà 34T"},
  {"input": "sửa: Toa nha 341", "target": "Tòa nhà 34T"},
  {"input": "sửa: Toa nha 34T, H0ang Dao Thuy", "target": "Tòa nhà 34T, Hoàng Đạo Thúy"},
  {"input": "sửa: Toa nha 34T, Hoang Da0 Thuy", "target": "Tòa nhà 34T, Hoàng Đạo Thúy"},
  {"input": "sửa: Toa nha 34T, Hoang Dao Thuy", "target": "Tòa nhà 34T, Hoàng Đạo Thúy"},

  {"input": "sửa: 4O Cat Linh", "target": "40 Cát Linh"},
  {"input": "sửa: 40 Cat LInh", "target": "40 Cát Linh"},
  {"input": "sửa: 40 Cat Linh, D0ng Da", "target": "40 Cát Linh, Đống Đa"},
  {"input": "sửa: 40 Cat Linh, Dong Da", "target": "40 Cát Linh, Đống Đa"},

  {"input": "sửa: ph0ng 101", "target": "phòng 101"},
  {"input": "sửa: phong 1O1", "target": "phòng 101"},
  {"input": "sửa: phong 101, tang l", "target": "phòng 101, tầng 1"},
  {"input": "sửa: phong 101, tang 1, l0 04-TT5B", "target": "phòng 101, tầng 1, lô 04-TT5B"},
  {"input": "sửa: phong 101, tang 1, lo O4-TT5B", "target": "phòng 101, tầng 1, lô 04-TT5B"},
  {"input": "sửa: phong 101, tang 1, lo 04-TT5B, khu d0 thi", "target": "phòng 101, tầng 1, lô 04-TT5B, khu đô thị"},
  {"input": "sửa: phong 101, tang 1, lo 04-TT5B, khu do thI", "target": "phòng 101, tầng 1, lô 04-TT5B, khu đô thị"},

  {"input": "sửa: Nha B7 ngo 416", "target": "Nhà 87 ngõ 416"},
  {"input": "sửa: Nha 87 ng0 416", "target": "Nhà 87 ngõ 416"},
  {"input": "sửa: Nha 87 ngo 41G", "target": "Nhà 87 ngõ 416"},
  {"input": "sửa: Nha 87 ngo 416 De La Thanh", "target": "Nhà 87 ngõ 416 Đê La Thành"},

  {"input": "sửa: Up c0working Space", "target": "Up coworking Space"},
  {"input": "sửa: Up coworking 5pace", "target": "Up coworking Space"},
  {"input": "sửa: Up coworking Space, B9 Lang Ha", "target": "Up coworking Space, 89 Láng Hạ"},
  {"input": "sửa: Up coworking Space, 89 Lang Ha", "target": "Up coworking Space, 89 Láng Hạ"},

  {"input": "sửa: l92 Ngo Duc Ke", "target": "192 Ngô Đức Kế"},
  {"input": "sửa: 192 Ng0 Duc Ke", "target": "192 Ngô Đức Kế"},
  {"input": "sửa: 192 Ngo Duc Ke, quan l", "target": "192 Ngô Đức Kế, quận 1"},
  {"input": "sửa: 192 Ngo Duc Ke, quan 1, H0 Chi Minh", "target": "192 Ngô Đức Kế, quận 1, Hồ Chí Minh"},
  {"input": "sửa: 192 Ngo Duc Ke, quan 1, Ho ChI Minh", "target": "192 Ngô Đức Kế, quận 1, Hồ Chí Minh"},

  {"input": "sửa: s0 5 Cong Truong Me Linh", "target": "số 5 Công Trường Mê Linh"},
  {"input": "sửa: so 5 C0ng Truong Me Linh", "target": "số 5 Công Trường Mê Linh"},
  {"input": "sửa: so 5 Cong Tru0ng Me Linh", "target": "số 5 Công Trường Mê Linh"},
  {"input": "sửa: so 5 Cong Truong Me LInh", "target": "số 5 Công Trường Mê Linh"},
  {"input": "sửa: so 5 Cong Truong Me Linh, phuong Ben Nghe", "target": "số 5 Công Trường Mê Linh, phường Bến Nghé"},
  {"input": "sửa: so 5 Cong Truong Me Linh, phuong Ben Nghe, quan l", "target": "số 5 Công Trường Mê Linh, phường Bến Nghé, quận 1"},

  {"input": "sửa: 9OA duong Mai Xuan Thuong", "target": "90A đường Mai Xuân Thưởng"},
  {"input": "sửa: 90A du0ng Mai Xuan Thuong", "target": "90A đường Mai Xuân Thưởng"},
  {"input": "sửa: 90A duong MaI Xuan Thuong", "target": "90A đường Mai Xuân Thưởng"},
  {"input": "sửa: 90A duong Mai Xuan Thuo ng", "target": "90A đường Mai Xuân Thưở ng"},
  {"input": "sửa: 90A duong Mai Xuan Thuong, tInh Gia Lai", "target": "90A đường Mai Xuân Thưởng, tỉnh Gia Lai"},

  {"input": "sửa: 9G/7/12B Pham Van Dong", "target": "96/7/12B Phạm Văn Đồng"},
  {"input": "sửa: 96/7/l2B Pham Van Dong", "target": "96/7/12B Phạm Văn Đồng"},
  {"input": "sửa: 96/7/12B Pham Van D0ng", "target": "96/7/12B Phạm Văn Đồng"},
  {"input": "sửa: 96/7/12B Pham Van Dong, thanh ph0 Pleiku", "target": "96/7/12B Phạm Văn Đồng, thành phố Pleiku"},
  {"input": "sửa: 96/7/12B Pham Van Dong, thanh pho PIeiku", "target": "96/7/12B Phạm Văn Đồng, thành phố Pleiku"},

  {"input": "sửa: l68 Ngo Gia Tu", "target": "168 Ngô Gia Tự"},
  {"input": "sửa: 168 Ng0 Gia Tu", "target": "168 Ngô Gia Tự"},
  {"input": "sửa: 168 Ngo GIa Tu", "target": "168 Ngô Gia Tự"},
  {"input": "sửa: 168 Ngo Gia Tu, thanh ph0 Ha Tinh", "target": "168 Ngô Gia Tự, thành phố Hà Tĩnh"},
  {"input": "sửa: 168 Ngo Gia Tu, thanh pho Ha TInh", "target": "168 Ngô Gia Tự, thành phố Hà Tĩnh"},

  {"input": "sửa: So 253 du0ng Tran Phu", "target": "Số 253 đường Trần Phú"},
  {"input": "sửa: So 253 duong Tran Phu", "target": "Số 253 đường Trần Phú"},
]

# %%
# ✅ 1. Install dependencies
# !pip install transformers datasets --quiet



# ✅ 3. Load pretrained VietT5
model_name = "VietAI/vit5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)


def preprocess(example):
    input_enc = tokenizer(example["input"], padding="max_length", truncation=True, max_length=64)
    target_enc = tokenizer(example["target"], padding="max_length", truncation=True, max_length=64)
    input_enc["labels"] = target_enc["input_ids"]
    return input_enc

dataset = Dataset.from_list(examples).map(preprocess)

# ✅ 5. Training configuration
training_args = TrainingArguments(
    output_dir="./vit5-finetuned",
    num_train_epochs=5,
    per_device_train_batch_size=1,
    save_strategy="no",
    logging_steps=1,
    fp16=True,  # ✅ Use mixed precision for speed
)

# ✅ 6. Train
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)
trainer.train()

# ✅ 7. Save model
model.save_pretrained("./vit5-finetuned")
tokenizer.save_pretrained("./vit5-finetuned")

print("✅ Done fine-tuning VietT5!")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/820k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...

# %%
# ✅ 2. Import libraries
import torch


from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
from datasets import Dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model = T5ForConditionalGeneration.from_pretrained("./vit5-finetuned")
tokenizer = T5Tokenizer.from_pretrained("./vit5-finetuned")

def correct_ocr(text):
    inputs = tokenizer("sửa: " + text, return_tensors="pt", max_length=64, truncation=True)
    output = model.generate(inputs.input_ids, max_length=64)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
print(correct_ocr(" nah b7 duong hng vong"))
# Out:
# nah 17 đường Hùng Vương

# %%
# !zip -r /content/fine-tuned.zip /content/vit5-finetuned
# Out:
#   adding: content/vit5-finetuned/ (stored 0%)
#   adding: content/vit5-finetuned/model.safetensors (deflated 8%)
#   adding: content/vit5-finetuned/spiece.model (deflated 53%)
#   adding: content/vit5-finetuned/special_tokens_map.json (deflated 85%)
#   adding: content/vit5-finetuned/config.json (deflated 49%)
#   adding: content/vit5-finetuned/tokenizer_config.json (deflated 94%)
#   adding: content/vit5-finetuned/added_tokens.json (deflated 83%)
#   adding: content/vit5-finetuned/generation_config.json (deflated 29%)
#   adding: content/vit5-finetuned/runs/ (stored 0%)
#   adding: content/vit5-finetuned/runs/Jun25_20-21-13_8b9b6a007994/ (stored 0%)
#   adding: content/vit5-finetuned/runs/Jun25_20-21-13_8b9b6a007994/events.out.tfevents.1750882882.8b9b6a007994.677.0 (deflated 72%)

# %%
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

html = open("soup.txt","r")

soup = BeautifulSoup(html, "html.parser")

# Extract loss data
steps = []
losses = []

for row in soup.find_all("tr")[1:]:  # skip header
    cols = row.find_all("td")
    if len(cols) == 2:
        steps.append(int(cols[0].text))
        losses.append(float(cols[1].text))

# Plot
plt.figure(figsize=(8, 4))
plt.plot(steps, losses, marker='o')
plt.xlabel("Step")
plt.ylabel("Training Loss")
plt.title("Training Loss Over Steps")
plt.grid(True)
plt.tight_layout()
plt.show()
